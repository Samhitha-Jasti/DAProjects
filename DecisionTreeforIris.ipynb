# %% [markdown]
# # Import Libraries and Read Data file

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
df=pd.read_csv('/content/Iris (1).csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
#Visualizing to find pattern
plt.scatter(df['SepalLengthCm'],df['SepalWidthCm'])
plt.show()

# %%
#Visualize 2 features based on target variable

sns.set_style('whitegrid')
sns.FacetGrid(df,hue='Species') \
  .map(plt.scatter,'SepalLengthCm','SepalWidthCm') \
  .add_legend()
plt.show()

# %% [markdown]
# We can observe from above plot that Iris-setosa is perfectly identified to other sepcies points for features- SepalLengthCm, SepalwidthCm

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
sns.pairplot(df.drop(['Id'],axis=1),hue='Species')
plt.show()

# %% [markdown]
# Blue(setosa) is perfectly seperated from other species in all graphs

# %%
#Adding new features to df
df['Sepal_diff']=df['SepalLengthCm']-df['SepalWidthCm']
df['Petal_diff']=df['PetalLengthCm']-df['PetalWidthCm']

# %%
df['Sepal_petal_len_diff']=df['SepalLengthCm']-df['PetalLengthCm']
df['Sepal_petal_width_diff']=df['SepalWidthCm']-df['PetalWidthCm']

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  Sepal_diff  Petal_diff  Sepal_petal_len_diff  \
# 0       Iris-setosa         1.6         1.2                   3.7
# ...

# %%
df['Sepal_petal_len_wid_diff']=df['SepalLengthCm']-df['PetalWidthCm']
df['Sepal_petal_wid_len_diff']=df['SepalWidthCm']-df['PetalLengthCm']
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  Sepal_diff  Petal_diff  Sepal_petal_len_diff  \
# 0       Iris-setosa         1.6         1.2                   3.7
# ...

# %% [markdown]
# Find Relationship between new feature based on class labels using pair plot

# %%
sns.pairplot(df[['Species','Sepal_diff','Petal_diff','Sepal_petal_len_diff','Sepal_petal_width_diff','Sepal_petal_len_wid_diff','Sepal_petal_wid_len_diff']],hue='Species')
plt.show()

# %% [markdown]
# # Building Classification model

# %%
#Dropping of Id column
df.drop(['Id'],axis=1,inplace=True)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species  \
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# ...

# %%
from sklearn import tree
import graphviz
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split, cross_val_score

''' Seperate Independent variables as x and Target Variables as y '''
X=df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm','Sepal_petal_wid_len_diff','Sepal_petal_width_diff']]
y=df['Species']

#Split the dataset into Actual Train and Actual Test Dataset
Xtrain,Xtest,Ytrain,Ytest=train_test_split(X,y,test_size=0.30,random_state=42)

#Split data into validation train and validation test
Xt,Xcv,Yt,Ycv=train_test_split(Xtrain,Ytrain,test_size=0.10,random_state=42)

''' Create Decision Tree Classifier and train it with training dataset '''

Iris_clf=DecisionTreeClassifier(criterion='gini',min_samples_split=2)
Iris_clf.fit(Xt,Yt)

#Visualize the tree formed on train dataset
tree.plot_tree(Iris_clf)
# Out:
# [Text(0.45454545454545453, 0.9166666666666666, 'X[2] <= 2.6\ngini = 0.665\nsamples = 94\nvalue = [30, 30, 34]'),
#  Text(0.36363636363636365, 0.75, 'gini = 0.0\nsamples = 30\nvalue = [30, 0, 0]'),
#  Text(0.5454545454545454, 0.75, 'X[4] <= -1.9\ngini = 0.498\nsamples = 64\nvalue = [0, 30, 34]'),
#  Text(0.36363636363636365, 0.5833333333333334, 'X[3] <= 1.75\ngini = 0.153\nsamples = 36\nvalue = [0, 3, 33]'),
#  Text(0.2727272727272727, 0.4166666666666667, 'X[2] <= 5.05\ngini = 0.49\nsamples = 7\nvalue = [0, 3, 4]'),
#  Text(0.18181818181818182, 0.25, 'X[0] <= 5.6\ngini = 0.375\nsamples = 4\nvalue = [0, 3, 1]'),
#  Text(0.09090909090909091, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.2727272727272727, 0.08333333333333333, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.36363636363636365, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.45454545454545453, 0.4166666666666667, 'gini = 0.0\nsamples = 29\nvalue = [0, 0, 29]'),
# ...

# %% [markdown]
# # VIsualizing Decision Tree using graphviz library

# %%
dot_data=tree.export_graphviz(Iris_clf,out_file=None)
graph=graphviz.Source(dot_data)
graph

# %%
#Model is trained
#Validate Decision tree using cross validation method to get accuracy or performance score of our model
print('Accuracy score is:',cross_val_score(Iris_clf,Xt,Yt,cv=3,scoring='accuracy').mean())
# Out:
# Accuracy score is: 0.9146505376344086

# %%
#Checking validation test data on our trained model and getting performance matrices
from sklearn.metrics import multilabel_confusion_matrix, accuracy_score
Y_hat=Iris_clf.predict(Xcv)

print('Accuracy score for validation test data is : ',accuracy_score(Ycv,Y_hat))
multilabel_confusion_matrix(Ycv,Y_hat)
# Out:
# Accuracy score for validation test data is :  0.8181818181818182
# array([[[10,  0],
#         [ 0,  1]],
#
#        [[ 3,  1],
#         [ 1,  6]],
#
#        [[ 7,  1],
#         [ 1,  2]]])

# %%
#Checking our model performance on actual unseen test data
YT_hat=Iris_clf.predict(Xtest)
YT_hat

print('Model Accuracy Score on totally unseen data(Xtest) is :',accuracy_score(Ytest,YT_hat)*100,'%')
multilabel_confusion_matrix(Ytest,YT_hat)
# Out:
# Model Accuracy Score on totally unseen data(Xtest) is : 100.0 %
# array([[[26,  0],
#         [ 0, 19]],
#
#        [[32,  0],
#         [ 0, 13]],
#
#        [[32,  0],
#         [ 0, 13]]])

# %%
#Training model on Actual train data

Iris_Fclf=DecisionTreeClassifier(criterion='gini',min_samples_split=2)
Iris_Fclf.fit(Xtrain,Ytrain)

#Visualize tree structure
tree.plot_tree(Iris_Fclf)
# Out:
# [Text(0.6, 0.9375, 'X[5] <= 1.9\ngini = 0.664\nsamples = 105\nvalue = [31, 37, 37]'),
#  Text(0.5, 0.8125, 'X[4] <= -1.9\ngini = 0.5\nsamples = 74\nvalue = [0, 37, 37]'),
#  Text(0.3, 0.6875, 'X[3] <= 1.75\ngini = 0.18\nsamples = 40\nvalue = [0, 4, 36]'),
#  Text(0.2, 0.5625, 'X[4] <= -2.6\ngini = 0.494\nsamples = 9\nvalue = [0, 4, 5]'),
#  Text(0.1, 0.4375, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.3, 0.4375, 'X[5] <= 0.9\ngini = 0.444\nsamples = 6\nvalue = [0, 4, 2]'),
#  Text(0.2, 0.3125, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.4, 0.3125, 'X[2] <= 5.05\ngini = 0.32\nsamples = 5\nvalue = [0, 4, 1]'),
#  Text(0.3, 0.1875, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0]'),
#  Text(0.5, 0.1875, 'X[0] <= 6.15\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1]'),
#  Text(0.4, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.6, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(0.4, 0.5625, 'gini = 0.0\nsamples = 31\nvalue = [0, 0, 31]'),
# ...

# %%
dot_data=tree.export_graphviz(Iris_Fclf,out_file=None)
graph=graphviz.Source(dot_data)
graph

# %% [markdown]
# # Checking the performance of model on Actual Test data

# %%
YT_Fhat=Iris_Fclf.predict(Xtest)
YT_Fhat
print('Model accuracy score on totally unseen data(Xtest) is:',accuracy_score(Ytest,YT_Fhat)*100,'%')
multilabel_confusion_matrix(Ytest,YT_Fhat)
# Out:
# Model accuracy score on totally unseen data(Xtest) is: 97.77777777777777 %
# array([[[26,  0],
#         [ 0, 19]],
#
#        [[32,  0],
#         [ 1, 12]],
#
#        [[31,  1],
#         [ 0, 13]]])

# %%
Test_point= [[5.4,3.0,3.5,1.5,-1.5,1.5],
             [6.5,2.8,4.6,1.5,-1.8,1.3]]
print(Iris_Fclf.predict(Test_point))
# Out:
# ['Iris-versicolor' 'Iris-versicolor']
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:451: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   "X does not have valid feature names, but"
